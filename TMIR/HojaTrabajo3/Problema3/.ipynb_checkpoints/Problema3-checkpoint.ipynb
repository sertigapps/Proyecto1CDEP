# %% [markdown]
# # Problema 3

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt 
from wordcloud import WordCloud, STOPWORDS
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
#nltk.download('punkt')
tweets = pd.read_csv("/Users/luisgarcia/tw_source.csv", encoding = "ISO-8859-1", header=None)

# %%
tweets.head()
# Out:
#    0           1                             2         3                4  \
# 0  0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                    5
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
dictCounter = {}
dictCorpora = {}
maxUsernames = []
def getContent(x):
    return x['Content']
for index, row in tweets.iterrows():
    pattern = re.compile("(?<![\w.-])@[A-Za-z][\w-]+")
    match = pattern.match(row[5])
    if match != None:
        username = match.group(0)
        if username not in dictCounter:
            dictCounter[username] = 0
        if username not in dictCorpora:
            dictCorpora[username] = []
        dictCounter[username]+=1
        dictCorpora[username].append({
            'Content' :  re.sub('(?<![\w.-])@[A-Za-z][\w-]+', '', row[5]),
            'Metadata': str(row[1])+','+str(row[2])+','+str(len(row[5]))
        })
wordnet_lemmatizer = WordNetLemmatizer()
stopwords = nltk.corpus.stopwords.words('english')
stopwords.append("n't")
for i in range(0,3):
    top = max(dictCounter, key=dictCounter.get)
    maxUsernames.append(top)
    dictCounter[top]=0
for i in range(len(maxUsernames)):
    print('Lugar #'+str(i+1)+' Usuario '+maxUsernames[i])
    c = ' '.join(list(map(getContent,dictCorpora[maxUsernames[i]])))
    text_tokens = word_tokenize(c)
    
    tokens_without_sw = [word for word in text_tokens if not word in stopwords]
    lematized = list(map(wordnet_lemmatizer.lemmatize, tokens_without_sw))
    #print(text_tokens)
    #print(tokens_without_sw)
    #print(lematized)
    wordcloud = WordCloud(width = 3000,max_words=10, height = 2000, random_state=1, background_color='black', colormap='Set2',
                          collocations=False, stopwords = STOPWORDS).generate(' '.join(lematized)) 
    # plot the WordCloud image                        
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 

    plt.show()
# Out:
# Lugar #1 Usuario @mileycyrus
# ['hahaha', 'dont', 'be', 'like', 'that', 'one', 'time', 'in', 'NY', 'when', 'you', 'got', '30', 'mins', 'of', 'sleep', 'then', 'got', 'sick', 'love', 'you', '!', '!', 'i', 'have', 'the', 'same', 'problem', ',', 'but', 'it', "'s", '4:43', 'here', '...', 'let', "'s", 'see', 'if', 'counting', 'works', '..', '1234', '...', '56', '57', '58', '...', '132', '133', '134', '...', 'no', 'z', "'s", 'for', 'me', '!', 'I', 'guess', 'counting', 'sheep', 'did', "n't", 'work', 'Hope', 'you', 'get', 'some', 'sleep', '!', 'I', 'would', 'too', 'if', 'it', 'meant', 'spending', 'a', 'day', 'in', 'heaven', 'w/my', 'mom', 'and', 'getting', 'to', 'see', 'her', 'again', '.', 'AWWW', 'u', 'seriously', 'have', 'the', 'cutest', 'dog', 'Miley', '!', 'Sorry', 'your', 'not', 'with', 'her', 'now', 'Hope', 'u', 'get', 'some', 'sleep', '!', 'xoxo', 'http', ':', '//twitpic.com/2xszg', '-', 'Napping', '?', 'At', 'this', 'point', 'you', 'may', 'need', 'a', 'few', 'of', 'those', '.', 'GMA', 'is', 'gon', 'na', 'come', 'early', '.', 'where', 'did', 'you', 'find', 'that', 'quote', '...', 'no', ',', 'donï¿½t', 'answer', ',', 'better', 'sleep', '!', 'xoxo', 'from', 'Germany', '(', 'where', 'itï¿½s', 'already', 'morning', ')', 'http', ':', '//twitpic.com/2y606', '-', 'I', 'want', 'a', 'Sofie', '!', 'She', "'s", 'helllza', 'cute', '.', 'ouch', 'mine', 'too', 'dude', ',', 'I', 'have', 'to', 'go', 'on', 'a', '4', 'mile', 'run', 'in', 'cold', 'ass', 'Boston', 'after', 'waking', 'up', 'just', 'now', '.', 'This', 'sucks', 'aww', 'I', 'feel', 'u', 'u', 'just', 'woke', 'up', 'for', 'school', 'hopefully', 'I', "'ll", 'meet', 'u', 'today', 'hah', '&', 'lt', ';', '3', 'awe', 'I', 'feel', 'u', 'i', 'just', 'woke', 'up', 'for', 'school', 'hopefully', 'we', 'both', 'have', 'a', 'better', 'rest', 'of', 'the', 'day', '..', '&', 'amp', ';', 'I', 'hope', 'that', 'includes', 'meeting', 'u', 'lol', 'wow', 'early', 'start', '.', 'I', 'havent', 'even', 'been', 'to', 'bed', 'yet', '.', 'Hope', 'your', 'tummy', 'feel', 'better', 'soon', 'love', 'your', 'aussie', 'fan', ';', ')', 'xxx', 'how', 'come', 'you', 'never', 'reply', 'to', 'me', '?', 'Aww', 'Chin', 'up', 'hun', '!', 'You', 'can', 'do', 'it', 'god', 'we', 'have', 'a', 'blizzard', 'here', 'GOOD', 'LUCK', '!', 'i', 'wish', 'i', 'could', 'be', 'thereee', 'goood', 'luck', 'today', '@', 'G', 'M', 'A', '....', 'No', 'one', 'would', 'take', 'me', 'I', 'love', 'you', '!', '!', '!', '!', '!', 'We', 'are', 'in', 'the', 'same', 'state', 'school', 'ugh', 'me', 'too', 'Billy', 'Ray', "'s", 'new', 'album', 'is', 'fantastic', '.', 'I', "'m", 'listening', 'it', 'on', 'iTunes', '.', 'I', "'d", 'buy', 'it', 'but', 'it', "'s", 'not', 'out', 'in', 'Aus', 'Make', 'it', 'come', 'out', 'here', '!', '..', 'You', 'on', 'the', 'tyra', 'show', ',', 'i', 'will', 'have', 'to', 'watch', 'that', 'online', ',', 'they', 'dont', 'show', 'it', 'in', 'the', 'UK', 'i', 'dont', 'think', '.', 'Miley', 'my', 'tummy', 'hurts', 'too', 'and', 'my', 'head', 'hurts', 'it', 'sounds', 'like', 'someone', 'is', 'pounding', 'on', 'my', 'head', '!', 'i', 'was', 'reading', 'your', 'book', 'today', '&', 'amp', ';', 'i', 'read', 'about', 'vanessa', ',', 'im', 'really', 'sorry', 'were', 'doing', 'a', 'fundraiser', '@', 'my', 'school', 'for', 'cystic', 'fibrosis', 'Iï¿½d', 'like', 'to', 'go', 'to', 'Madrid', 'to', 'see', 'you', 'but', 'I', 'think', 'itï¿½s', 'not', 'possible', 'anyway', ',', 'Iï¿½ll', 'watch', 'you', 'on', 'tuesday', 'on', '&', 'quot', ';', 'El', 'hormiguero', '&', 'quot', ';', 'i', 'love', 'you', ',', 'answer', 'me', '!', 'i', "'m", 'your', 'number', 'one', 'faaan', '!', 'Have', 'fun', 'away', 'from', 'america', 'haha', '..', 'Safe', 'Jpurney', 'Cos', 'Imm', 'One', 'Off', 'Uur', 'Fans', 'Lol', 'Thaa', 'Mii', '&', 'amp', ';', '&', 'amp', ';', 'Uue', 'Never', 'Reply', 'To', 'Anythiiin', 'I', 'Send', 'Uue', '!', 'Not', 'Fair', 'lol', 'YOU', 'FLIGHT', 'TO', 'GERMANY', 'BUT', 'NOT', 'TO', 'AUSTRIA', 'WHY', '?', '?', '?', 'YOU', 'FLIGHT', 'TO', 'GERMANY', 'BUT', 'NOT', 'TO', 'AUS ...
# ['hahaha', 'dont', 'like', 'one', 'time', 'NY', 'got', '30', 'mins', 'sleep', 'got', 'sick', 'love', '!', '!', 'problem', ',', "'s", '4:43', '...', 'let', "'s", 'see', 'counting', 'works', '..', '1234', '...', '56', '57', '58', '...', '132', '133', '134', '...', 'z', "'s", '!', 'I', 'guess', 'counting', 'sheep', 'work', 'Hope', 'get', 'sleep', '!', 'I', 'would', 'meant', 'spending', 'day', 'heaven', 'w/my', 'mom', 'getting', 'see', '.', 'AWWW', 'u', 'seriously', 'cutest', 'dog', 'Miley', '!', 'Sorry', 'Hope', 'u', 'get', 'sleep', '!', 'xoxo', 'http', ':', '//twitpic.com/2xszg', '-', 'Napping', '?', 'At', 'point', 'may', 'need', '.', 'GMA', 'gon', 'na', 'come', 'early', '.', 'find', 'quote', '...', ',', 'donï¿½t', 'answer', ',', 'better', 'sleep', '!', 'xoxo', 'Germany', '(', 'itï¿½s', 'already', 'morning', ')', 'http', ':', '//twitpic.com/2y606', '-', 'I', 'want', 'Sofie', '!', 'She', "'s", 'helllza', 'cute', '.', 'ouch', 'mine', 'dude', ',', 'I', 'go', '4', 'mile', 'run', 'cold', 'ass', 'Boston', 'waking', '.', 'This', 'sucks', 'aww', 'I', 'feel', 'u', 'u', 'woke', 'school', 'hopefully', 'I', "'ll", 'meet', 'u', 'today', 'hah', '&', 'lt', ';', '3', 'awe', 'I', 'feel', 'u', 'woke', 'school', 'hopefully', 'better', 'rest', 'day', '..', '&', 'amp', ';', 'I', 'hope', 'includes', 'meeting', 'u', 'lol', 'wow', 'early', 'start', '.', 'I', 'havent', 'even', 'bed', 'yet', '.', 'Hope', 'tummy', 'feel', 'better', 'soon', 'love', 'aussie', 'fan', ';', ')', 'xxx', 'come', 'never', 'reply', '?', 'Aww', 'Chin', 'hun', '!', 'You', 'god', 'blizzard', 'GOOD', 'LUCK', '!', 'wish', 'could', 'thereee', 'goood', 'luck', 'today', '@', 'G', 'M', 'A', '....', 'No', 'one', 'would', 'take', 'I', 'love', '!', '!', '!', '!', '!', 'We', 'state', 'school', 'ugh', 'Billy', 'Ray', "'s", 'new', 'album', 'fantastic', '.', 'I', "'m", 'listening', 'iTunes', '.', 'I', "'d", 'buy', "'s", 'Aus', 'Make', 'come', '!', '..', 'You', 'tyra', 'show', ',', 'watch', 'online', ',', 'dont', 'show', 'UK', 'dont', 'think', '.', 'Miley', 'tummy', 'hurts', 'head', 'hurts', 'sounds', 'like', 'someone', 'pounding', 'head', '!', 'reading', 'book', 'today', '&', 'amp', ';', 'read', 'vanessa', ',', 'im', 'really', 'sorry', 'fundraiser', '@', 'school', 'cystic', 'fibrosis', 'Iï¿½d', 'like', 'go', 'Madrid', 'see', 'I', 'think', 'itï¿½s', 'possible', 'anyway', ',', 'Iï¿½ll', 'watch', 'tuesday', '&', 'quot', ';', 'El', 'hormiguero', '&', 'quot', ';', 'love', ',', 'answer', '!', "'m", 'number', 'one', 'faaan', '!', 'Have', 'fun', 'away', 'america', 'haha', '..', 'Safe', 'Jpurney', 'Cos', 'Imm', 'One', 'Off', 'Uur', 'Fans', 'Lol', 'Thaa', 'Mii', '&', 'amp', ';', '&', 'amp', ';', 'Uue', 'Never', 'Reply', 'To', 'Anythiiin', 'I', 'Send', 'Uue', '!', 'Not', 'Fair', 'lol', 'YOU', 'FLIGHT', 'TO', 'GERMANY', 'BUT', 'NOT', 'TO', 'AUSTRIA', 'WHY', '?', '?', '?', 'YOU', 'FLIGHT', 'TO', 'GERMANY', 'BUT', 'NOT', 'TO', 'AUSTRIA', 'WHY', '?', '?', '?', 'Ahh', '..', 'Now', 'I', "'m", 'sad', 'I', '2', 'days', 'ago', 'YOU', 'FLIGHT', 'TO', 'GERMANY', 'BUT', 'NOT', 'TO', 'AUSTRIA', 'WHY', '?', '?', '?', "'s", 'cool', '-', 'wo', 'able', 'see', 'well', 'ill', 'go', 'cinema', 'watch', 'premier', 'brother', ':', 'Ca', 'wait', '!', '!', "'re", 'lucky', 'actually', 'car', ',', 'aha', '.', 'well', 'working', 'one', '.', 'crashed', 'mine', '.', 'lol', 'cares', '.', 'audi', ',', 'tomato', ',', 'tomayto', '.', '(', 'wow', ',', 'im', 'really', 'twittering', 'mileycyrus', ')', 'hope', 'fab', 'time', 'uk', 'miley', '!', '!', '!', '!', '!', 'wish', 'could', 'meet', '!', '.......', 'know', 'wat', "'s", 'like', 'leavin', "'", "'em", 'yuh', 'wan', 'na', 'leave', 'Awehh', 'hate', 'half', 'leave', '!', 'names', 'ShannonMyleigh', 'hahaha', '!', 'http', ':', '//twitpic.com/3goxn', '-', 'WOAH', '!', 'c', 'y.', 'I', 'blame', 'u.', 'would', 'hate', 'private', 'life', 'hey', 'hun', '!', 'couldnt', 'imagine', 'traveling', 'like', '.', 'keep', 'head', '!', 'inspiration', 'many', '.', 'live', '!', 'I', 'school', 'tomorrow', '!', 'Booo ...
# ['hahaha', 'dont', 'like', 'one', 'time', 'NY', 'got', '30', 'min', 'sleep', 'got', 'sick', 'love', '!', '!', 'problem', ',', "'s", '4:43', '...', 'let', "'s", 'see', 'counting', 'work', '..', '1234', '...', '56', '57', '58', '...', '132', '133', '134', '...', 'z', "'s", '!', 'I', 'guess', 'counting', 'sheep', 'work', 'Hope', 'get', 'sleep', '!', 'I', 'would', 'meant', 'spending', 'day', 'heaven', 'w/my', 'mom', 'getting', 'see', '.', 'AWWW', 'u', 'seriously', 'cutest', 'dog', 'Miley', '!', 'Sorry', 'Hope', 'u', 'get', 'sleep', '!', 'xoxo', 'http', ':', '//twitpic.com/2xszg', '-', 'Napping', '?', 'At', 'point', 'may', 'need', '.', 'GMA', 'gon', 'na', 'come', 'early', '.', 'find', 'quote', '...', ',', 'donï¿½t', 'answer', ',', 'better', 'sleep', '!', 'xoxo', 'Germany', '(', 'itï¿½s', 'already', 'morning', ')', 'http', ':', '//twitpic.com/2y606', '-', 'I', 'want', 'Sofie', '!', 'She', "'s", 'helllza', 'cute', '.', 'ouch', 'mine', 'dude', ',', 'I', 'go', '4', 'mile', 'run', 'cold', 'as', 'Boston', 'waking', '.', 'This', 'suck', 'aww', 'I', 'feel', 'u', 'u', 'woke', 'school', 'hopefully', 'I', "'ll", 'meet', 'u', 'today', 'hah', '&', 'lt', ';', '3', 'awe', 'I', 'feel', 'u', 'woke', 'school', 'hopefully', 'better', 'rest', 'day', '..', '&', 'amp', ';', 'I', 'hope', 'includes', 'meeting', 'u', 'lol', 'wow', 'early', 'start', '.', 'I', 'havent', 'even', 'bed', 'yet', '.', 'Hope', 'tummy', 'feel', 'better', 'soon', 'love', 'aussie', 'fan', ';', ')', 'xxx', 'come', 'never', 'reply', '?', 'Aww', 'Chin', 'hun', '!', 'You', 'god', 'blizzard', 'GOOD', 'LUCK', '!', 'wish', 'could', 'thereee', 'goood', 'luck', 'today', '@', 'G', 'M', 'A', '....', 'No', 'one', 'would', 'take', 'I', 'love', '!', '!', '!', '!', '!', 'We', 'state', 'school', 'ugh', 'Billy', 'Ray', "'s", 'new', 'album', 'fantastic', '.', 'I', "'m", 'listening', 'iTunes', '.', 'I', "'d", 'buy', "'s", 'Aus', 'Make', 'come', '!', '..', 'You', 'tyra', 'show', ',', 'watch', 'online', ',', 'dont', 'show', 'UK', 'dont', 'think', '.', 'Miley', 'tummy', 'hurt', 'head', 'hurt', 'sound', 'like', 'someone', 'pounding', 'head', '!', 'reading', 'book', 'today', '&', 'amp', ';', 'read', 'vanessa', ',', 'im', 'really', 'sorry', 'fundraiser', '@', 'school', 'cystic', 'fibrosis', 'Iï¿½d', 'like', 'go', 'Madrid', 'see', 'I', 'think', 'itï¿½s', 'possible', 'anyway', ',', 'Iï¿½ll', 'watch', 'tuesday', '&', 'quot', ';', 'El', 'hormiguero', '&', 'quot', ';', 'love', ',', 'answer', '!', "'m", 'number', 'one', 'faaan', '!', 'Have', 'fun', 'away', 'america', 'haha', '..', 'Safe', 'Jpurney', 'Cos', 'Imm', 'One', 'Off', 'Uur', 'Fans', 'Lol', 'Thaa', 'Mii', '&', 'amp', ';', '&', 'amp', ';', 'Uue', 'Never', 'Reply', 'To', 'Anythiiin', 'I', 'Send', 'Uue', '!', 'Not', 'Fair', 'lol', 'YOU', 'FLIGHT', 'TO', 'GERMANY', 'BUT', 'NOT', 'TO', 'AUSTRIA', 'WHY', '?', '?', '?', 'YOU', 'FLIGHT', 'TO', 'GERMANY', 'BUT', 'NOT', 'TO', 'AUSTRIA', 'WHY', '?', '?', '?', 'Ahh', '..', 'Now', 'I', "'m", 'sad', 'I', '2', 'day', 'ago', 'YOU', 'FLIGHT', 'TO', 'GERMANY', 'BUT', 'NOT', 'TO', 'AUSTRIA', 'WHY', '?', '?', '?', "'s", 'cool', '-', 'wo', 'able', 'see', 'well', 'ill', 'go', 'cinema', 'watch', 'premier', 'brother', ':', 'Ca', 'wait', '!', '!', "'re", 'lucky', 'actually', 'car', ',', 'aha', '.', 'well', 'working', 'one', '.', 'crashed', 'mine', '.', 'lol', 'care', '.', 'audi', ',', 'tomato', ',', 'tomayto', '.', '(', 'wow', ',', 'im', 'really', 'twittering', 'mileycyrus', ')', 'hope', 'fab', 'time', 'uk', 'miley', '!', '!', '!', '!', '!', 'wish', 'could', 'meet', '!', '.......', 'know', 'wat', "'s", 'like', 'leavin', "'", "'em", 'yuh', 'wan', 'na', 'leave', 'Awehh', 'hate', 'half', 'leave', '!', 'name', 'ShannonMyleigh', 'hahaha', '!', 'http', ':', '//twitpic.com/3goxn', '-', 'WOAH', '!', 'c', 'y.', 'I', 'blame', 'u.', 'would', 'hate', 'private', 'life', 'hey', 'hun', '!', 'couldnt', 'imagine', 'traveling', 'like', '.', 'keep', 'head', '!', 'inspiration', 'many', '.', 'live', '!', 'I', 'school', 'tomorrow', '!', 'Boooring', ',' ...
# Lugar #2 Usuario @tommcfly
# ['hey', 'saw', 'u', 'guys', 'play', '@', 'pushover', '..', 'did', "n't", 'get', '2', 'meet', 'u', 'tho', 'cuz', 'of', 'th', 'HUGE', 'line', 'i', 'was', 'very', 'upset', '=', "'", '(', 'lol', '..', 'a', 'msg', 'would', 'make', 'up', '4', 'it', '!', 'Good', 'morning', 'Tom', '!', 'Why', 'ca', "n't", 'I', 'send', 'you', 'a', 'message', '?', 'This', 'is', 'too', 'short', 'for', 'the', 'question', 'I', 'have', 'Well', 'to', 'bad', 'for', 'me', 'I', 'guess', '..', 'did', 'you', 'know', 'that', 'johnsons', 'baby', 'use', 'animals', 'like', 'cute', 'bunnies', 'to', 'test', 'their', 'products', '?', 'hey', ',', 'no', 'chance', 'of', 'adding', 'brighton', 'or', 'eastbourne', 'to', 'the', 'UCAP', 'tour', '?', 'gutted', 'im', 'missing', 'out', 'this', 'time', 'round', 'i', 'love', 'you', 'guys', '!', 'have', 'fun', 'tom', ',', 'i', 'need', 'to', 'buy', 'eclipse', 'too', 'but', 'i', 'have', 'no', 'money', '.', 'sad', 'timess', 'are', 'you', 'coming', 'to', 'play', 'at', 'Plymouth', 'again', 'this', 'year', 'cus', 'i', 'cant', 'go', 'to', 'the', 'ucap', 'tour', 'cus', 'you', 'arent', 'coming', 'anywhere', 'near', 'me', 'oxo', ':', 'O', 'starbucks', '!', 'never', 'tehe', 'oooh', 'now', 'i', 'want', 'one', 'aw', 'i', 'want', 'a', 'starbucks', 'i', 'have', 'to', 'still', 'read', 'eclipse', 'as', 'well', '!', 'do', "n't", 'watch', 'twilight', 'the', 'movie', 'though', 'if', 'you', 'want', 'to', 'keep', 'liking', 'the', 'books', '.', 'movie', "'s", 'bad', 'http', ':', '//twitpic.com/3iquy', '-', 'i', 'miss', 'your', 'old', 'hairstyle', 'daniel', 'but', 'you', 'still', 'look', 'great', 'hoping', 'you', 'love', 'amsterdam', '!', 'enjoy', 'your', 'sunbathing', '?', 'lol', 'its', 'cloudy', 'over', 'here', 'in', 'america', 'I', 'wish', 'i', "'d", 'be', 'there', 'with', 'you', 'guys', 'awww', 'when', 'are', 'you', 'coming', 'back', '?', 'because', 'are', 'you', 'going', 'to', 'the', 'star', 'trek', 'premier', '?', 'xx', 'i', 'feel', 'sad', ',', 'i', 'could', "n't", 'travel', 'to', 'see', 'you', 'guys', 'in', 'Amsterdam', '!', 'can', 'you', 'come', 'to', 'Norway', 'soon', '?', 'awww', 'ive', 'been', 'trying', 'to', 'get', 'you', 'played', 'on', 'the', 'radio', 'and', 'they', 'not', 'playing', 'u', 'you', 'know', 'you', 'love', 'brazil', 'more', 'than', 'anyone', 'country', '*', 'I', "'m", 'jealous', '*', 'Love', 'you', 'I', 'hope', 'you', "'ll", 'come', 'to', 'Germany', 'one', 'day', '...', 'I', 'really', 'would', 'like', 'to', 'see', 'you', 'guys', 'live', 'one', 'day', '!', 'Are', 'you', 'ever', 'gon', 'na', 'come', 'to', 'Sweden', '?', '!', 'x', 'Hey', ',', 'Tommy', '!', '!', 'How', 'was', 'the', 'concert', 'here', 'in', 'Amsterdam', '?', 'I', 'wish', 'I', 'could', 'be', 'there', '!', 'but', 'I', 'could', "n't", '.....', 'srry', 'for', 'that', '!', 'Love', 'you', 'xoxo', 'anyway', ',', 'i', 'take', 'it', 'your', 'comin', 'home', 'tomorrow', '?', 'the', 'weathers', 'been', 'rubbish', 'today', ',', 'well', 'in', 'newcastle', 'anyway', 'why', 'did', "n't", 'you', 'twitter', 'during', 'the', 'gig', ',', 'tom', '?', 'im', 'upset', ';', ')', 'If', 'only', 'there', 'were', 'no', 'time', 'zones', '....', 'i', 'only', 'start', 'getting', 'your', 'morning', 'tweets', 'as', 'i', 'go', 'to', 'bed', '...', 'Solution', ':', 'move', 'to', 'the', 'US', ';', ')', 'baby', ',', 'upppppp', 'earlyyyyyy', 'a', 'lotttttt', '.', ':', 'O', 'give', 'me', 'your', 'breakfast', '?', 'hey', 'tom', ',', 'hope', 'you', 'guys', 'have', 'a', 'great', 'tour', ',', 'i', 'live', 'in', 'australia', 'so', 'i', 'cant', 'go', 'http', ':', '//twitpic.com/3kygb', '-', 'uuuh', 'that', 'seems', 'much', 'more', 'delicious', 'that', 'my', 'poor', 'coffee', 'It', "'s", 'like', '4', 'am', 'here', ',', 'I', 'did', "n't", 'even', 'go', 't', '...', 'ive', 'never', 'been', 'on', 'a', 'plane', '.', 'so', 'sorry', 'no', '.', 'how', 'many', 'times', 'have', 'you', 'been', 'on', 'a', 'plane', '?', 'i', 'always', 'set', 'the', 'alarm', 'off', '.', 'ALWAYS', '.', 'nah', '.', 'had', 'my', 'sweets', 'taken',  ...
# ['hey', 'saw', 'u', 'guys', 'play', '@', 'pushover', '..', 'get', '2', 'meet', 'u', 'tho', 'cuz', 'th', 'HUGE', 'line', 'upset', '=', "'", '(', 'lol', '..', 'msg', 'would', 'make', '4', '!', 'Good', 'morning', 'Tom', '!', 'Why', 'ca', 'I', 'send', 'message', '?', 'This', 'short', 'question', 'I', 'Well', 'bad', 'I', 'guess', '..', 'know', 'johnsons', 'baby', 'use', 'animals', 'like', 'cute', 'bunnies', 'test', 'products', '?', 'hey', ',', 'chance', 'adding', 'brighton', 'eastbourne', 'UCAP', 'tour', '?', 'gutted', 'im', 'missing', 'time', 'round', 'love', 'guys', '!', 'fun', 'tom', ',', 'need', 'buy', 'eclipse', 'money', '.', 'sad', 'timess', 'coming', 'play', 'Plymouth', 'year', 'cus', 'cant', 'go', 'ucap', 'tour', 'cus', 'arent', 'coming', 'anywhere', 'near', 'oxo', ':', 'O', 'starbucks', '!', 'never', 'tehe', 'oooh', 'want', 'one', 'aw', 'want', 'starbucks', 'still', 'read', 'eclipse', 'well', '!', 'watch', 'twilight', 'movie', 'though', 'want', 'keep', 'liking', 'books', '.', 'movie', "'s", 'bad', 'http', ':', '//twitpic.com/3iquy', '-', 'miss', 'old', 'hairstyle', 'daniel', 'still', 'look', 'great', 'hoping', 'love', 'amsterdam', '!', 'enjoy', 'sunbathing', '?', 'lol', 'cloudy', 'america', 'I', 'wish', "'d", 'guys', 'awww', 'coming', 'back', '?', 'going', 'star', 'trek', 'premier', '?', 'xx', 'feel', 'sad', ',', 'could', 'travel', 'see', 'guys', 'Amsterdam', '!', 'come', 'Norway', 'soon', '?', 'awww', 'ive', 'trying', 'get', 'played', 'radio', 'playing', 'u', 'know', 'love', 'brazil', 'anyone', 'country', '*', 'I', "'m", 'jealous', '*', 'Love', 'I', 'hope', "'ll", 'come', 'Germany', 'one', 'day', '...', 'I', 'really', 'would', 'like', 'see', 'guys', 'live', 'one', 'day', '!', 'Are', 'ever', 'gon', 'na', 'come', 'Sweden', '?', '!', 'x', 'Hey', ',', 'Tommy', '!', '!', 'How', 'concert', 'Amsterdam', '?', 'I', 'wish', 'I', 'could', '!', 'I', 'could', '.....', 'srry', '!', 'Love', 'xoxo', 'anyway', ',', 'take', 'comin', 'home', 'tomorrow', '?', 'weathers', 'rubbish', 'today', ',', 'well', 'newcastle', 'anyway', 'twitter', 'gig', ',', 'tom', '?', 'im', 'upset', ';', ')', 'If', 'time', 'zones', '....', 'start', 'getting', 'morning', 'tweets', 'go', 'bed', '...', 'Solution', ':', 'move', 'US', ';', ')', 'baby', ',', 'upppppp', 'earlyyyyyy', 'lotttttt', '.', ':', 'O', 'give', 'breakfast', '?', 'hey', 'tom', ',', 'hope', 'guys', 'great', 'tour', ',', 'live', 'australia', 'cant', 'go', 'http', ':', '//twitpic.com/3kygb', '-', 'uuuh', 'seems', 'much', 'delicious', 'poor', 'coffee', 'It', "'s", 'like', '4', ',', 'I', 'even', 'go', '...', 'ive', 'never', 'plane', '.', 'sorry', '.', 'many', 'times', 'plane', '?', 'always', 'set', 'alarm', '.', 'ALWAYS', '.', 'nah', '.', 'sweets', 'taken', 'away', 'though', '.', 'poor', 'ears', 'hurt', 'like', 'hell', 'whole', 'flight', '.', 'TOM', '!', '!', '!', '!', "'re", 'pilot', '?', '?', '?', 'since', '..', 'u', 'still', 'show', 'us', 'ray-bans', '!', '!', 'I', 'wish', 'I', 'could', 'tweet', 'England', '.', 'hey', 'guys', 'back', 'England', '!', '!', '!', 'Welll', 'super', 'great', 'last', 'night', '!', '!', 'Ca', 'wait', 'next', 'gig', '!', 'Yes', '!', '!', '!', '!', '!', 'It', 'always', 'beeps', ',', 'I', 'get', 'even', 'nervous', 'embarrassed', '.', 'It', "'s", 'braces', 'haha', 'poor', 'coming', 'nice', 'warm', 'weather', 'rubbish', 'cold', 'one', 'well', 'ive', 'never', 'even', 'plane', 'excuse', ',', 'I', "'m", 'disappointed', 'Amsterdam', 'got', 'Down', 'Goes', 'Another', 'One', 'Sydney', '!', '!', '!', 'heeey', '!', 'Will', 'please', 'Ucap', 'Tour', 'Ireland', '?', 'We', 'see', 'year', '&', 'amp', ';', 'sucks', 'please', 'tweet', 'back', '!', '&', 'amp', ';', 'make', 'day', '!', 'xx', 'My', 'mum', 'cba', 'make', '1', 'X', 'mmm', 'Tasty', ',', "'", 'r', 'making', 'hungry', 'eh', ',', 'yous', 'cooming', 'back', 'oz', 'sooon', '?', 'cus', 'didnt', 'get', 'see', 'yous', 'play', 'last', 'time', 'cus', 'grounded', '.', 'plss', 'come', 'back', '=', ']', 'x', 'dinner', 'full', 'stickii', 'date', 'p ...
# ['hey', 'saw', 'u', 'guy', 'play', '@', 'pushover', '..', 'get', '2', 'meet', 'u', 'tho', 'cuz', 'th', 'HUGE', 'line', 'upset', '=', "'", '(', 'lol', '..', 'msg', 'would', 'make', '4', '!', 'Good', 'morning', 'Tom', '!', 'Why', 'ca', 'I', 'send', 'message', '?', 'This', 'short', 'question', 'I', 'Well', 'bad', 'I', 'guess', '..', 'know', 'johnson', 'baby', 'use', 'animal', 'like', 'cute', 'bunny', 'test', 'product', '?', 'hey', ',', 'chance', 'adding', 'brighton', 'eastbourne', 'UCAP', 'tour', '?', 'gutted', 'im', 'missing', 'time', 'round', 'love', 'guy', '!', 'fun', 'tom', ',', 'need', 'buy', 'eclipse', 'money', '.', 'sad', 'times', 'coming', 'play', 'Plymouth', 'year', 'cu', 'cant', 'go', 'ucap', 'tour', 'cu', 'arent', 'coming', 'anywhere', 'near', 'oxo', ':', 'O', 'starbucks', '!', 'never', 'tehe', 'oooh', 'want', 'one', 'aw', 'want', 'starbucks', 'still', 'read', 'eclipse', 'well', '!', 'watch', 'twilight', 'movie', 'though', 'want', 'keep', 'liking', 'book', '.', 'movie', "'s", 'bad', 'http', ':', '//twitpic.com/3iquy', '-', 'miss', 'old', 'hairstyle', 'daniel', 'still', 'look', 'great', 'hoping', 'love', 'amsterdam', '!', 'enjoy', 'sunbathing', '?', 'lol', 'cloudy', 'america', 'I', 'wish', "'d", 'guy', 'awww', 'coming', 'back', '?', 'going', 'star', 'trek', 'premier', '?', 'xx', 'feel', 'sad', ',', 'could', 'travel', 'see', 'guy', 'Amsterdam', '!', 'come', 'Norway', 'soon', '?', 'awww', 'ive', 'trying', 'get', 'played', 'radio', 'playing', 'u', 'know', 'love', 'brazil', 'anyone', 'country', '*', 'I', "'m", 'jealous', '*', 'Love', 'I', 'hope', "'ll", 'come', 'Germany', 'one', 'day', '...', 'I', 'really', 'would', 'like', 'see', 'guy', 'live', 'one', 'day', '!', 'Are', 'ever', 'gon', 'na', 'come', 'Sweden', '?', '!', 'x', 'Hey', ',', 'Tommy', '!', '!', 'How', 'concert', 'Amsterdam', '?', 'I', 'wish', 'I', 'could', '!', 'I', 'could', '.....', 'srry', '!', 'Love', 'xoxo', 'anyway', ',', 'take', 'comin', 'home', 'tomorrow', '?', 'weather', 'rubbish', 'today', ',', 'well', 'newcastle', 'anyway', 'twitter', 'gig', ',', 'tom', '?', 'im', 'upset', ';', ')', 'If', 'time', 'zone', '....', 'start', 'getting', 'morning', 'tweet', 'go', 'bed', '...', 'Solution', ':', 'move', 'US', ';', ')', 'baby', ',', 'upppppp', 'earlyyyyyy', 'lotttttt', '.', ':', 'O', 'give', 'breakfast', '?', 'hey', 'tom', ',', 'hope', 'guy', 'great', 'tour', ',', 'live', 'australia', 'cant', 'go', 'http', ':', '//twitpic.com/3kygb', '-', 'uuuh', 'seems', 'much', 'delicious', 'poor', 'coffee', 'It', "'s", 'like', '4', ',', 'I', 'even', 'go', '...', 'ive', 'never', 'plane', '.', 'sorry', '.', 'many', 'time', 'plane', '?', 'always', 'set', 'alarm', '.', 'ALWAYS', '.', 'nah', '.', 'sweet', 'taken', 'away', 'though', '.', 'poor', 'ear', 'hurt', 'like', 'hell', 'whole', 'flight', '.', 'TOM', '!', '!', '!', '!', "'re", 'pilot', '?', '?', '?', 'since', '..', 'u', 'still', 'show', 'u', 'ray-bans', '!', '!', 'I', 'wish', 'I', 'could', 'tweet', 'England', '.', 'hey', 'guy', 'back', 'England', '!', '!', '!', 'Welll', 'super', 'great', 'last', 'night', '!', '!', 'Ca', 'wait', 'next', 'gig', '!', 'Yes', '!', '!', '!', '!', '!', 'It', 'always', 'beep', ',', 'I', 'get', 'even', 'nervous', 'embarrassed', '.', 'It', "'s", 'brace', 'haha', 'poor', 'coming', 'nice', 'warm', 'weather', 'rubbish', 'cold', 'one', 'well', 'ive', 'never', 'even', 'plane', 'excuse', ',', 'I', "'m", 'disappointed', 'Amsterdam', 'got', 'Down', 'Goes', 'Another', 'One', 'Sydney', '!', '!', '!', 'heeey', '!', 'Will', 'please', 'Ucap', 'Tour', 'Ireland', '?', 'We', 'see', 'year', '&', 'amp', ';', 'suck', 'please', 'tweet', 'back', '!', '&', 'amp', ';', 'make', 'day', '!', 'xx', 'My', 'mum', 'cba', 'make', '1', 'X', 'mmm', 'Tasty', ',', "'", 'r', 'making', 'hungry', 'eh', ',', 'yous', 'cooming', 'back', 'oz', 'sooon', '?', 'cu', 'didnt', 'get', 'see', 'yous', 'play', 'last', 'time', 'cu', 'grounded', '.', 'plss', 'come', 'back', '=', ']', 'x', 'dinner', 'full', 'stickii', 'date', 'pudding', 'pudding', 'hahaha' ...
# Lugar #3 Usuario @ddlovato
# ['ummmmm', 'i', 'cant', 'find', 'it', '.', 'Do', 'you', 'hate', 'us', '?', '?', 'Please', 'do', "n't", 'Wish', 'that', 'i', 'could', 'see', 'it', '..', 'Thats', 'the', 'downside', 'of', 'living', 'in', 'Sweden', '..', 'Good', 'Luck', 'anyway', 'hey', 'demi', ',', 'wen', 'are', 'you', 'and', 'selena', 'gon', 'na', 'do', 'another', 'video', '?', 'i', 'miss', 'them', 'ahhhh', 'i', 'wish', 'i', 'could', 'go', 'to', 'the', 'dallas', 'show', '...', 'but', 'i', 'wont', 'be', 'near', 'there', 'then', 'I', 'just', 'saw', 'your', 'tour', 'dates', 'and', 'now', 'I', 'am', 'sad', '..', 'You', 'come', 'to', 'houston', 'two', 'days', 'before', 'I', 'get', 'home', 'from', 'vacation', 'sonny', 'with', 'a', 'chance', 'in', 'the', 'UK', ',', 'only', '6', 'more', 'days', '.', 'I', 'ca', "n't", 'wait', ',', 'but', 'I', "'ll", 'miss', 'it', '.', 'I', "'m", 'at', 'the', 'McFly', 'concert', 'hmm', '..', 'I', "'ll", 'record', 'it', 'demii', '!', '!', 'how', 'is', 'your', 'stage', 'going', 'to', 'be', '?', '?', 'i', 'dont', 'know', 'what', 'kind', 'of', 'seats', 'to', 'look', 'for', 'when', 'i', 'buy', 'them', 'on', 'tuesdayy', 'hi', 'demi', ',', 'at', 'which', 'airport', 'in', 'Germany', 'were', 'you', '?', 'If', 'you', 'were', 'in', 'Munich', 'I', 'missed', 'you', 'by', 'like', 'a', 'day', 'if', 'you', "'d", 'answer', 'that', "'ll", 'be', 'grea', 'awww', '.', 'why', '.', 'omg', 'i', 'really', 'wana', 'c', 'ure', 'new', 'show', 'but', 'it', 'is', 'not', 'out', 'here', 'HEY', 'DEMI', 'WHY', 'DO', 'YOU', 'NOT', 'COME', 'TO', 'AUSTRIA', '?', '?', '?', 'WHYY', '?', '?', '!', '!', 'IS', 'NOT', 'MY', 'FAULT', '!', ',', 'MY', 'PARENTS', 'ARE', 'BUSY', 'FOR', '1TH', 'TIME', '!', 'I', 'FEEL', 'UPSET', '...', '(', '(', '(', 'u', ')', 'Hi', ',', 'How', 'long', 'are', 'you', 'in', 'London', '?', 'I', 'have', 'uni', 'lectures', 'during', 'your', 'show', 'on', 'Wednesday', 'do', 'u', 'even', 'get', 'to', 'know', 'me', 'messages', '?', 'we', "'ll", 'miss', 'you', 'toooooooo', 'xoxo', 'HEY', 'DEMI', 'WHY', 'DO', 'YOU', 'NOT', 'COME', 'TO', 'AUSTRIA', '?', '?', '?', 'AND', 'YEAH', 'I', 'WISH', 'YOU', 'A', 'GOOD', 'FLIGHT', 'HEY', 'DEMI', 'WHY', 'DO', 'YOU', 'NOT', 'COME', 'TO', 'AUSTRIA', '?', '?', '?', 'AND', 'YEAH', 'I', 'WISH', 'YOU', 'A', 'GOOD', 'FLIGHT', 'Ilove', 'ou', 'demi', 'you', 'are', 'great', 'i', 'wish', 'you', 'would', 'reply', 'to', 'mee', '...', 'Wish', 'you', 'were', 'coming', 'to', 'Toronto', '.', 'i', 'wish', 'i', 'could', 'see', 'your', 'concert', '.', 'I', 'FRUCKIN', "'", 'LUV', 'U', '!', '!', '!', '!', '!', '&', 'lt', ';', '3333', 'UR', 'SO', 'FUNNY', 'ON', 'UR', 'SHOW', '!', '!', 'xD', 'i', 'wish', 'i', 'can', 'meet', 'u', 'in', 'person', '!', '!', 'Your', 'in', 'germany', '?', 'i', 'am', 'too', ',', 'baumholder', '.', 'i', 'never', 'seen', 'a', 'celebrity', 'in', 'concert', '.', "'cept", 'Lil', 'Jon', '.', '.', 'Why', 'do', 'you', 'hate', 'me', '?', 'Lol', 'I', "'m", 'so', 'angry', 'that', 'i', 'cant', 'come', 'to', 'youre', 'concert', ',', 'Demi', '!', '!', '!', '!', 'ca', "n't", 'wait', 'to', 'travel', 'I', 'know', 'how', 'you', 'feel', '...', 'From', 'america', 'to', 'europe', 'is', 'a', 'nightmare', '!', '!', 'Are', 'you', 'in', 'Madrid', 'now', '?', 'OMG', '!', 'haha', 'you', 'are', 'so', 'tired', 'go', 'to', 'sleep', 'and', 'have', 'fun', 'in', 'Spain', '!', 'Iï¿½m', 'sad', 'you', 'was', 'in', 'Germany', 'and', 'i', 'couldnï¿½t', 'see', 'you', '...', '-', 'i', 'dont', 'get', 'your', 'jokee', 'why', 'are', 'u', 'there', '?', 'come', 'to', 'italy', 'what', 'you', "'ve", 'been', 'in', 'germany', 'where', 'you', 'have', 'been', '?', '?', 'please', 'please', 'answer', 'OMG', 'i', 'cant', 'believe', 'you', 'actually', 'pit', 'stopped', 'in', 'GERMANY', '!', '!', 'and', 'i', 'didnt', 'know', 'awwww', 'i', 'wan', 'na', 'meet', 'u', '!', '!', '!', '!', '!', '!', '!', 'love', 'you', '&', 'lt', ';', '33', 'Hey', '!', 'Demi', '?', 'U', 'still', 'there', '?', 'omg', '!', 'I', 'wish', 'I', 'could', 'be', 'there', '!', 'I', 'ca', "n't", 'wait', 'to',  ...
# ['ummmmm', 'cant', 'find', '.', 'Do', 'hate', 'us', '?', '?', 'Please', 'Wish', 'could', 'see', '..', 'Thats', 'downside', 'living', 'Sweden', '..', 'Good', 'Luck', 'anyway', 'hey', 'demi', ',', 'wen', 'selena', 'gon', 'na', 'another', 'video', '?', 'miss', 'ahhhh', 'wish', 'could', 'go', 'dallas', 'show', '...', 'wont', 'near', 'I', 'saw', 'tour', 'dates', 'I', 'sad', '..', 'You', 'come', 'houston', 'two', 'days', 'I', 'get', 'home', 'vacation', 'sonny', 'chance', 'UK', ',', '6', 'days', '.', 'I', 'ca', 'wait', ',', 'I', "'ll", 'miss', '.', 'I', "'m", 'McFly', 'concert', 'hmm', '..', 'I', "'ll", 'record', 'demii', '!', '!', 'stage', 'going', '?', '?', 'dont', 'know', 'kind', 'seats', 'look', 'buy', 'tuesdayy', 'hi', 'demi', ',', 'airport', 'Germany', '?', 'If', 'Munich', 'I', 'missed', 'like', 'day', "'d", 'answer', "'ll", 'grea', 'awww', '.', '.', 'omg', 'really', 'wana', 'c', 'ure', 'new', 'show', 'HEY', 'DEMI', 'WHY', 'DO', 'YOU', 'NOT', 'COME', 'TO', 'AUSTRIA', '?', '?', '?', 'WHYY', '?', '?', '!', '!', 'IS', 'NOT', 'MY', 'FAULT', '!', ',', 'MY', 'PARENTS', 'ARE', 'BUSY', 'FOR', '1TH', 'TIME', '!', 'I', 'FEEL', 'UPSET', '...', '(', '(', '(', 'u', ')', 'Hi', ',', 'How', 'long', 'London', '?', 'I', 'uni', 'lectures', 'show', 'Wednesday', 'u', 'even', 'get', 'know', 'messages', '?', "'ll", 'miss', 'toooooooo', 'xoxo', 'HEY', 'DEMI', 'WHY', 'DO', 'YOU', 'NOT', 'COME', 'TO', 'AUSTRIA', '?', '?', '?', 'AND', 'YEAH', 'I', 'WISH', 'YOU', 'A', 'GOOD', 'FLIGHT', 'HEY', 'DEMI', 'WHY', 'DO', 'YOU', 'NOT', 'COME', 'TO', 'AUSTRIA', '?', '?', '?', 'AND', 'YEAH', 'I', 'WISH', 'YOU', 'A', 'GOOD', 'FLIGHT', 'Ilove', 'ou', 'demi', 'great', 'wish', 'would', 'reply', 'mee', '...', 'Wish', 'coming', 'Toronto', '.', 'wish', 'could', 'see', 'concert', '.', 'I', 'FRUCKIN', "'", 'LUV', 'U', '!', '!', '!', '!', '!', '&', 'lt', ';', '3333', 'UR', 'SO', 'FUNNY', 'ON', 'UR', 'SHOW', '!', '!', 'xD', 'wish', 'meet', 'u', 'person', '!', '!', 'Your', 'germany', '?', ',', 'baumholder', '.', 'never', 'seen', 'celebrity', 'concert', '.', "'cept", 'Lil', 'Jon', '.', '.', 'Why', 'hate', '?', 'Lol', 'I', "'m", 'angry', 'cant', 'come', 'youre', 'concert', ',', 'Demi', '!', '!', '!', '!', 'ca', 'wait', 'travel', 'I', 'know', 'feel', '...', 'From', 'america', 'europe', 'nightmare', '!', '!', 'Are', 'Madrid', '?', 'OMG', '!', 'haha', 'tired', 'go', 'sleep', 'fun', 'Spain', '!', 'Iï¿½m', 'sad', 'Germany', 'couldnï¿½t', 'see', '...', '-', 'dont', 'get', 'jokee', 'u', '?', 'come', 'italy', "'ve", 'germany', '?', '?', 'please', 'please', 'answer', 'OMG', 'cant', 'believe', 'actually', 'pit', 'stopped', 'GERMANY', '!', '!', 'didnt', 'know', 'awwww', 'wan', 'na', 'meet', 'u', '!', '!', '!', '!', '!', '!', '!', 'love', '&', 'lt', ';', '33', 'Hey', '!', 'Demi', '?', 'U', 'still', '?', 'omg', '!', 'I', 'wish', 'I', 'could', '!', 'I', 'ca', 'wait', 'see', 'u', '13.6', 'Madrid', '!', 'Love', '!', 'pity', 'I', 'wont', 'go', 'show', 'brazil', 'bad', "'re", 'summer', 'tour', 'comming', 'Norway', 'omg', ',', "'s", 'Madrid', '!', 'wish', ',', 'live', 'far', 'place', 'fun', ',', 'demi', '!', 'love', 'xxx', 'http', ':', '//twitpic.com/3lwfk', '-', 'Welcome', 'Spain', 'Demi', '!', '!', 'I', "'m", 'Spain', 'Madrid', '.', 'would', 'like', 'Madrid', 'great', 'day', 'Demi', 'school', 'haha', 'x', 'pleaseeee', 'come', 'manchester', ',', 'UK', '...', 'every', 'band', 'always', 'London', '..', 'difficult', 'keep', 'traveling', 'London', 'trying', 'scare', 'Why', 'sad', 'face', '?', 'Do', 'Worry', '.', 'Be', 'Happy', '!', 'happened', ',', 'demi', '?', 'dunno', 'demi', 'ignore', 'dumb', 'know', 'others', 'tell', 'true', 'actually', 'figure', 'out.urperfect', 'fun', 'London', 'shame', 'I', "'m", 'gunna', 'though', ',', 'coz', 'I', "'m", 'school', '!', 'id', 'love', 'meet', ',', 'abouts', 'london', '...', 'I', 'know', 'right', '.', 'I', 'think', 'I', "'m", 'okay', '.', 'But', 'people', 'think', 'I', "'m", 'fat', 'I', "'m", 'like', '46KG', "'m", '15', '.', 'I', 'understand', '.', 'Why', '&', 'qu ...
# ['ummmmm', 'cant', 'find', '.', 'Do', 'hate', 'u', '?', '?', 'Please', 'Wish', 'could', 'see', '..', 'Thats', 'downside', 'living', 'Sweden', '..', 'Good', 'Luck', 'anyway', 'hey', 'demi', ',', 'wen', 'selena', 'gon', 'na', 'another', 'video', '?', 'miss', 'ahhhh', 'wish', 'could', 'go', 'dallas', 'show', '...', 'wont', 'near', 'I', 'saw', 'tour', 'date', 'I', 'sad', '..', 'You', 'come', 'houston', 'two', 'day', 'I', 'get', 'home', 'vacation', 'sonny', 'chance', 'UK', ',', '6', 'day', '.', 'I', 'ca', 'wait', ',', 'I', "'ll", 'miss', '.', 'I', "'m", 'McFly', 'concert', 'hmm', '..', 'I', "'ll", 'record', 'demii', '!', '!', 'stage', 'going', '?', '?', 'dont', 'know', 'kind', 'seat', 'look', 'buy', 'tuesdayy', 'hi', 'demi', ',', 'airport', 'Germany', '?', 'If', 'Munich', 'I', 'missed', 'like', 'day', "'d", 'answer', "'ll", 'grea', 'awww', '.', '.', 'omg', 'really', 'wana', 'c', 'ure', 'new', 'show', 'HEY', 'DEMI', 'WHY', 'DO', 'YOU', 'NOT', 'COME', 'TO', 'AUSTRIA', '?', '?', '?', 'WHYY', '?', '?', '!', '!', 'IS', 'NOT', 'MY', 'FAULT', '!', ',', 'MY', 'PARENTS', 'ARE', 'BUSY', 'FOR', '1TH', 'TIME', '!', 'I', 'FEEL', 'UPSET', '...', '(', '(', '(', 'u', ')', 'Hi', ',', 'How', 'long', 'London', '?', 'I', 'uni', 'lecture', 'show', 'Wednesday', 'u', 'even', 'get', 'know', 'message', '?', "'ll", 'miss', 'toooooooo', 'xoxo', 'HEY', 'DEMI', 'WHY', 'DO', 'YOU', 'NOT', 'COME', 'TO', 'AUSTRIA', '?', '?', '?', 'AND', 'YEAH', 'I', 'WISH', 'YOU', 'A', 'GOOD', 'FLIGHT', 'HEY', 'DEMI', 'WHY', 'DO', 'YOU', 'NOT', 'COME', 'TO', 'AUSTRIA', '?', '?', '?', 'AND', 'YEAH', 'I', 'WISH', 'YOU', 'A', 'GOOD', 'FLIGHT', 'Ilove', 'ou', 'demi', 'great', 'wish', 'would', 'reply', 'mee', '...', 'Wish', 'coming', 'Toronto', '.', 'wish', 'could', 'see', 'concert', '.', 'I', 'FRUCKIN', "'", 'LUV', 'U', '!', '!', '!', '!', '!', '&', 'lt', ';', '3333', 'UR', 'SO', 'FUNNY', 'ON', 'UR', 'SHOW', '!', '!', 'xD', 'wish', 'meet', 'u', 'person', '!', '!', 'Your', 'germany', '?', ',', 'baumholder', '.', 'never', 'seen', 'celebrity', 'concert', '.', "'cept", 'Lil', 'Jon', '.', '.', 'Why', 'hate', '?', 'Lol', 'I', "'m", 'angry', 'cant', 'come', 'youre', 'concert', ',', 'Demi', '!', '!', '!', '!', 'ca', 'wait', 'travel', 'I', 'know', 'feel', '...', 'From', 'america', 'europe', 'nightmare', '!', '!', 'Are', 'Madrid', '?', 'OMG', '!', 'haha', 'tired', 'go', 'sleep', 'fun', 'Spain', '!', 'Iï¿½m', 'sad', 'Germany', 'couldnï¿½t', 'see', '...', '-', 'dont', 'get', 'jokee', 'u', '?', 'come', 'italy', "'ve", 'germany', '?', '?', 'please', 'please', 'answer', 'OMG', 'cant', 'believe', 'actually', 'pit', 'stopped', 'GERMANY', '!', '!', 'didnt', 'know', 'awwww', 'wan', 'na', 'meet', 'u', '!', '!', '!', '!', '!', '!', '!', 'love', '&', 'lt', ';', '33', 'Hey', '!', 'Demi', '?', 'U', 'still', '?', 'omg', '!', 'I', 'wish', 'I', 'could', '!', 'I', 'ca', 'wait', 'see', 'u', '13.6', 'Madrid', '!', 'Love', '!', 'pity', 'I', 'wont', 'go', 'show', 'brazil', 'bad', "'re", 'summer', 'tour', 'comming', 'Norway', 'omg', ',', "'s", 'Madrid', '!', 'wish', ',', 'live', 'far', 'place', 'fun', ',', 'demi', '!', 'love', 'xxx', 'http', ':', '//twitpic.com/3lwfk', '-', 'Welcome', 'Spain', 'Demi', '!', '!', 'I', "'m", 'Spain', 'Madrid', '.', 'would', 'like', 'Madrid', 'great', 'day', 'Demi', 'school', 'haha', 'x', 'pleaseeee', 'come', 'manchester', ',', 'UK', '...', 'every', 'band', 'always', 'London', '..', 'difficult', 'keep', 'traveling', 'London', 'trying', 'scare', 'Why', 'sad', 'face', '?', 'Do', 'Worry', '.', 'Be', 'Happy', '!', 'happened', ',', 'demi', '?', 'dunno', 'demi', 'ignore', 'dumb', 'know', 'others', 'tell', 'true', 'actually', 'figure', 'out.urperfect', 'fun', 'London', 'shame', 'I', "'m", 'gunna', 'though', ',', 'coz', 'I', "'m", 'school', '!', 'id', 'love', 'meet', ',', 'abouts', 'london', '...', 'I', 'know', 'right', '.', 'I', 'think', 'I', "'m", 'okay', '.', 'But', 'people', 'think', 'I', "'m", 'fat', 'I', "'m", 'like', '46KG', "'m", '15', '.', 'I', 'understand', '.', 'Why', '&', 'quot', '; ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-4348cc8abb04> in <module>
#      43     plt.tight_layout(pad = 0)
#      44
# ---> 45     plt.show()
#      46
#      47
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     334     """
#     335     _warn_if_gui_out_of_main_thread()
# --> 336     return _backend_mod.show(*args, **kwargs)
#     337
#     338
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2746             renderer.stop_rasterizing()
#    2747
# -> 2748         mimage._draw_list_compositing_images(renderer, self, artists)
#    2749
#    2750         renderer.close_group('axes')
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     637         else:
#     638             im, l, b, trans = self.make_image(
# --> 639                 renderer, renderer.get_image_magnification())
#     640             if im is not None:
#     641                 renderer.draw_image(gc, l, b, im)
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     922                 else self.figure.bbox)
#     923         return self._make_image(self._A, bbox, transformed_bbox, clip,
# --> 924                                 magnification, unsampled=unsampled)
#     925
#     926     def _check_unsampled_image(self):
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     546                 alpha = self._get_scalar_alpha()
#     547                 output_alpha = _resample(  # resample alpha channel
# --> 548                     self, A[..., 3], out_shape, t, alpha=alpha)
#     549                 output = _resample(  # resample rgb channels
#     550                     self, _rgb_to_rgba(A[..., :3]), out_shape, t, alpha=alpha)
#
# ~/.conda/envs/Script/lib/python3.7/site-packages/matplotlib/image.py in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     196                     alpha,
#     197                     image_obj.get_filternorm(),
# --> 198                     image_obj.get_filterrad())
#     199     return out
#     200
#
# KeyboardInterrupt:
