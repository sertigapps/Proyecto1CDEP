# %% [markdown]
# # Proyecto #1

# %%
import numpy as np 
import tensorflow as tf 
import matplotlib.pyplot as plt 
datos = np.load('proyecto_training_data.npy')

# %%
precios = datos[:,0]
overall = datos[:,1]

# %%
plt.scatter(overall, precios) 
plt.xlabel('Overall') 
plt.ylabel('Precio') 
plt.title("Verificando correlacion") 
plt.show()
